# %%
from predict import *
# Out:
# Using TensorFlow backend.

# %%
model_skirt_length = load_model('skirt_length')
model_skirt_length.load_weights('model_resnet_skirt_length.h5', by_name=True)
model_neck_design = load_model('neck_design')
model_neck_design.load_weights('model_resnet_neck_design.h5', by_name=True)
model_coat_length = load_model('coat_length')
model_coat_length.load_weights('model_resnet_coat_length.h5', by_name=True)
model_collar_design = load_model('collar_design')
model_collar_design.load_weights('model_resnet_collar_design.h5', by_name=True)

# %%
model_lapel_design = load_model2('lapel_design')
model_lapel_design.load_weights('model_InceptionV3lapel_design.h5', by_name=True)
model_neckline_design = load_model2('neckline_design')
model_neckline_design.load_weights('model_InceptionV3neckline_design.h5', by_name=True)
model_pant_length = load_model2('pant_length')
model_pant_length.load_weights('model_InceptionV3pant_length.h5', by_name=True)
model_sleeve_length = load_model2('sleeve_length')
model_sleeve_length.load_weights('model_InceptionV3sleeve_length.h5', by_name=True)

# %%
path = './data/Images/skirt_length_labels/6feaab35e50a1f0c159a13815637d0c7.jpg'

pred_result = predict(path, model_skirt_length, model_neck_design, model_coat_length, model_collar_design)
# Out:
# ...
# 1/1 [==============================] - 3s 3s/step
# The skirt length of the image below is Floor Length
#  The coat length of the image below is Ankle&Floor Length
#  The neck design of the image below is Invisible
#  The collar design of the image below is Invisible

# %%
path = './data/Images/skirt_length_labels/6feaab35e50a1f0c159a13815637d0c7.jpg'
pred_result = predict2(path, model_lapel_design, model_neckline_design, model_pant_length, model_sleeve_length)
# Out:
# ...
# 1/1 [==============================] - 9s 9s/step
# The lapel design of the image below is Invisible
#  The neckline design of the image below is Square Neckline
#  The pant length of the image below is Invisible
#  The sleeve length of the image below is Elbow Sleeves

# %%
path = './data/Images/skirt_length_labels/a61b116a9fa68ff9885b81187150eae0.jpg'
pred_result = predict(path, model_skirt_length, model_neck_design, model_coat_length, model_collar_design)
# Out:
# ...
# 1/1 [==============================] - 0s 56ms/step
# The skirt length of the image below is Floor Length
#  The coat length of the image below is Ankle&Floor Length
#  The neck design of the image below is Invisible
#  The collar design of the image below is Invisible

# %%
path = './data/Images/skirt_length_labels/a61b116a9fa68ff9885b81187150eae0.jpg'
pred_result = predict2(path, model_lapel_design, model_neckline_design, model_pant_length, model_sleeve_length)
# Out:
# ...
# 1/1 [==============================] - 0s 58ms/step
# The lapel design of the image below is Invisible
#  The neckline design of the image below is Round Neckline
#  The pant length of the image below is Invisible
#  The sleeve length of the image below is Sleeveless

# %%
path = './data/Images/skirt_length_labels/d307664b4bcf09ad55ed4c44cf4cca27.jpg'
pred_result = predict(path, model_skirt_length, model_neck_design, model_coat_length, model_collar_design)
# Out:
# ...
# 1/1 [==============================] - 0s 49ms/step
# The skirt length of the image below is Ankle Length
#  The coat length of the image below is Ankle&Floor Length
#  The neck design of the image below is Low Turtle Neck
#  The collar design of the image below is Invisible

# %%
path = './data/Images/skirt_length_labels/d307664b4bcf09ad55ed4c44cf4cca27.jpg'
pred_result = predict2(path, model_lapel_design, model_neckline_design, model_pant_length, model_sleeve_length)
# Out:
# ...
# 1/1 [==============================] - 0s 61ms/step
# The lapel design of the image below is Invisible
#  The neckline design of the image below is Round Neckline
#  The pant length of the image below is Invisible
#  The sleeve length of the image below is Long Sleeves

# %%
path = './data/Images/skirt_length_labels/9df6ef6680e946c13c9968f3fe7c1509.jpg'
pred_result = predict(path, model_skirt_length, model_neck_design, model_coat_length, model_collar_design)
# Out:
# ...
# 1/1 [==============================] - 0s 50ms/step
# The skirt length of the image below is Midi Length
#  The coat length of the image below is Ankle&Floor Length
#  The neck design of the image below is Invisible
#  The collar design of the image below is Invisible

# %%
path = './data/Images/skirt_length_labels/9df6ef6680e946c13c9968f3fe7c1509.jpg'
pred_result = predict2(path, model_lapel_design, model_neckline_design, model_pant_length, model_sleeve_length)
# Out:
# ...
# 1/1 [==============================] - 0s 56ms/step
# The lapel design of the image below is Invisible
#  The neckline design of the image below is V Neckline
#  The pant length of the image below is Invisible
#  The sleeve length of the image below is Short Sleeves

# %%
path = './data/Images/neck_design_labels/1b2a92726cbfc5bcaaa1419742c1987b.jpg'
pred_result = predict(path, model_skirt_length, model_neck_design, model_coat_length, model_collar_design)
# Out:
# ...
# 1/1 [==============================] - 0s 45ms/step
# The skirt length of the image below is Short Length
#  The coat length of the image below is Micro Length
#  The neck design of the image below is Turtle Neck
#  The collar design of the image below is Invisible

# %%
path = './data/Images/neck_design_labels/1b2a92726cbfc5bcaaa1419742c1987b.jpg'
pred_result = predict2(path, model_lapel_design, model_neckline_design, model_pant_length, model_sleeve_length)
# Out:
# ...
# 1/1 [==============================] - 0s 60ms/step
# The lapel design of the image below is Invisible
#  The neckline design of the image below is Invisible
#  The pant length of the image below is Short Pant
#  The sleeve length of the image below is Long Sleeves

# %%
path = './data/Images/collar_design_labels/c28045592164f5aa1f3aa98d9bd492b5.jpg'
pred_result = predict(path, model_skirt_length, model_neck_design, model_coat_length, model_collar_design)
# Out:
# ...
# 1/1 [==============================] - 0s 45ms/step
# The skirt length of the image below is Knee Length
#  The coat length of the image below is Knee Length
#  The neck design of the image below is Low Turtle Neck
#  The collar design of the image below is Puritan Collar

# %%
path = './data/Images/collar_design_labels/c28045592164f5aa1f3aa98d9bd492b5.jpg'
pred_result = predict2(path, model_lapel_design, model_neckline_design, model_pant_length, model_sleeve_length)
# Out:
# ...
# 1/1 [==============================] - 0s 55ms/step
# The lapel design of the image below is Plus Size Shawl
#  The neckline design of the image below is V Neckline
#  The pant length of the image below is Invisible
#  The sleeve length of the image below is Long Sleeves

# %%
path = './data/Images/coat_length_labels/832152d97a339aecbd1450bf7633cf55.jpg'
pred_result = predict(path, model_skirt_length, model_neck_design, model_coat_length, model_collar_design)
# Out:
# ...
# 1/1 [==============================] - 0s 56ms/step
# The skirt length of the image below is Floor Length
#  The coat length of the image below is Ankle&Floor Length
#  The neck design of the image below is Invisible
#  The collar design of the image below is Invisible

# %%
path = './data/Images/coat_length_labels/832152d97a339aecbd1450bf7633cf55.jpg'
pred_result = predict2(path, model_lapel_design, model_neckline_design, model_pant_length, model_sleeve_length)
# Out:
# ...
# 1/1 [==============================] - 0s 60ms/step
# The lapel design of the image below is Plus Size Shawl
#  The neckline design of the image below is Deep V Neckline
#  The pant length of the image below is Invisible
#  The sleeve length of the image below is Long Sleeves

# %%
path = './data/Images/coat_length_labels/0926e0987194feda3c764ea269cc8b07.jpg'
pred_result = predict(path, model_skirt_length, model_neck_design, model_coat_length, model_collar_design)
# Out:
# ...
# 1/1 [==============================] - 0s 61ms/step
# The skirt length of the image below is Short Length
#  The coat length of the image below is Regular Length
#  The neck design of the image below is Invisible
#  The collar design of the image below is Invisible

# %%
path = './data/Images/coat_length_labels/0926e0987194feda3c764ea269cc8b07.jpg'
pred_result = predict2(path, model_lapel_design, model_neckline_design, model_pant_length, model_sleeve_length)
# Out:
# ...
# 1/1 [==============================] - 0s 55ms/step
# The lapel design of the image below is Invisible
#  The neckline design of the image below is Round Neckline
#  The pant length of the image below is Short Pant
#  The sleeve length of the image below is Wrist Length

# %%
path = './data/Images/pant_length_labels/33854f640f69a04708dcdeb72faa1651.jpg'
pred_result = predict(path, model_skirt_length, model_neck_design, model_coat_length, model_collar_design)
# Out:
# ...
# 1/1 [==============================] - 0s 55ms/step
# The skirt length of the image below is Invisible
#  The coat length of the image below is Ankle&Floor Length
#  The neck design of the image below is Invisible
#  The collar design of the image below is Shirt Collar

# %%
path = './data/Images/pant_length_labels/33854f640f69a04708dcdeb72faa1651.jpg'
pred_result = predict2(path, model_lapel_design, model_neckline_design, model_pant_length, model_sleeve_length)
# Out:
# ...
# 1/1 [==============================] - 0s 54ms/step
# The lapel design of the image below is Invisible
#  The neckline design of the image below is Invisible
#  The pant length of the image below is 3/4 Length
#  The sleeve length of the image below is Sleeveless
